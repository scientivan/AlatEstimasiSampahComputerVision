# %%
import torch
from IPython.display import Image

# %%
torch.__version__
# Out:
# '1.12.1+cu116'

# %%
torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 3050 Laptop GPU', major=8, minor=6, total_memory=4095MB, multi_processor_count=16)

# %%
from tqdm import tqdm
import IProgress
from ipywidgets import IntProgress

# %%
torch.cuda.get_arch_list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 torch.cuda.get_arch_list()
#
# NameError: name 'torch' is not defined

# %%
# %cd yolov5-master
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5-master'
# d:\Programming\PythonProjects\OPSI\yolov5-master

# %%
# !python train.py --img 416 --batch 15 --epochs 50 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=50, batch_size=15, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2022-10-7 Python-3.8.5 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp30/weights/best.pt --img 200 --conf 0.25 --source test3.jpeg
# Out:
# detect: weights=['runs/train/exp30/weights/best.pt'], source=test3.jpeg, data=data\coco128.yaml, imgsz=[200, 200], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2022-10-7 Python-3.8.5 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size [200, 200] must be multiple of max stride 32, updating to [224, 224]
# image 1/1 D:\Programming\PythonProjects\OPSI\yolov5-master\test3.jpeg: 224x128 1 organik, 3 botol plastiks, 6 metals, 10.0ms
# Speed: 0.0ms pre-process, 10.0ms inference, 3.5ms NMS per image at shape (1, 3, 224, 224)
# ...

# %%
# !python export.py --weights runs/train/exp30/weights/best.pt --include tflite --img 416
# Out:
# Model: "model"
# export: data=D:\Programming\PythonProjects\OPSI\yolov5-master\data\coco128.yaml, weights=['runs/train/exp29/weights/best.pt'], imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5  2022-10-7 Python-3.8.5 torch-1.12.1+cu116 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs\train\exp29\weights\best.pt with output shape (1, 10647, 12) (13.7 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.10.0...
#
#                  from  n    params  module                                  arguments
# ...

# %%
# %cd yolov5-master

# %%
# !python detect.py --weights runs\train\exp28\weights\best-fp16.tflite --img 200 --conf 0.25 --source gelaskaca.jpg
# Out:
# detect: weights=['runs\\train\\exp28\\weights\\best-fp16.tflite'], source=gelaskaca.jpg, data=data\coco128.yaml, imgsz=[200, 200], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2022-10-7 Python-3.8.5 torch-1.12.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Loading runs\train\exp28\weights\best-fp16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING  --img-size [200, 200] must be multiple of max stride 32, updating to [224, 224]
# image 1/1 D:\Programming\PythonProjects\OPSI\yolov5-master\gelaskaca.jpg: 224x224 1 kaca, 41.2ms
# ...
